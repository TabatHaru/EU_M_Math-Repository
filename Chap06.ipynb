# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
pwd
# Out:
# '/content'

# %%
mkdir chap6

# %%
cd ./chap6/
# Out:
# /content/chap6

# %%
import requests, zipfile
from io import StringIO
import io

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00356/student.zip'

r = requests.get(url, stream=True)

z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
# Exercise6-1
hier_df1 = DataFrame(
    np.arange(12).reshape((3,4)),
    index = [['c', 'd', 'd'],[1,2,1]],
    columns= [
        ['Kyoto','Nagoya','Hokkaido','Kyoto'],
        ['Yellow','Yellow','Red','Blue']
    ]
)

hier_df1.index.names = ['key1','key2']
hier_df1.columns.names = ['city','color']
hier_df1

hier_df1['Kyoto']
# Out:
# color      Yellow  Blue
# key1 key2
# c    1          0     3
# d    2          4     7
#      1          8    11

# %%
# Exercise6-2
hier_df1.mean(level='city',axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-984322be7651> in <cell line: 2>()
#       1 # Exercise6-2
# ----> 2 hier_df1.mean(level='city',axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11554             **kwargs,
#   11555         ):
# > 11556             return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11557
#   11558         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11199         **kwargs,
#   11200     ) -> Series | float:
# > 11201         return self._stat_function(
#   11202             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11152             nv.validate_median((), kwargs)
#   11153         else:
# > 11154             nv.validate_stat_func((), kwargs, fname=name)
#   11155
#   11156         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/compat/numpy/function.py in __call__(self, args, kwargs, fname, max_fname_arg_count, method)
#      78                 validate_args(fname, args, max_fname_arg_count, self.defaults)
#      79             elif method == "kwargs":
# ---> 80                 validate_kwargs(fname, kwargs, self.defaults)
#      81             elif method == "both":
#      82                 validate_args_and_kwargs(
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_validators.py in validate_kwargs(fname, kwargs, compat_args)
#     160     """
#     161     kwds = kwargs.copy()
# --> 162     _check_for_invalid_keys(fname, kwargs, compat_args)
#     163     _check_for_default_values(fname, kwds, compat_args)
#     164
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_validators.py in _check_for_invalid_keys(fname, kwargs, compat_args)
#     134     if diff:
#     135         bad_arg = list(diff)[0]
# --> 136         raise TypeError(f"{fname}() got an unexpected keyword argument '{bad_arg}'")
#     137
#     138
#
# TypeError: mean() got an unexpected keyword argument 'level'

# %%
# Exercise6-3
hier_data_frame1.sum(level='key2')

# %%
# Exercise6-4
data4 = {
    'id' : ['0','1','2','3','4','6','8','11','12','13'],
    'city' :['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo','Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'birth_day' :[1990,1989,1992,1997,1982,1991,1988,1990,1995,1981],
    'name' :['Hiroshi','Akiko','Yuri','Satoru','Steeve','Mituru','Aoi','Tarou','Suguru','Mitsuo']
}

df4 = DataFrame(data4)

# %%
data5 = {
    'id':['0','1','3','6','8'],
    'math':[20,30,50,70,90],
    'english':[30,50,50,70,20],
    'sex':['M','F','F','M','M'],
    'index_num':[0,1,2,3,4]
}
df5 = DataFrame(data5)
df5
# Out:
#   id  math  english sex  index_num
# 0  0    20       30   M          0
# 1  1    30       50   F          1
# 2  3    50       50   F          2
# 3  6    70       70   M          3
# 4  8    90       20   M          4

# %%
# Exercise6-4
pd.merge(df4, df5, on='id')
# Out:
#   id      city  birth_day     name  math  english sex  index_num
# 0  0     Tokyo       1990  Hiroshi    20       30   M          0
# 1  1     Osaka       1989    Akiko    30       50   F          1
# 2  3  Hokkaido       1997   Satoru    50       50   F          2
# 3  6     Tokyo       1991   Mituru    70       70   M          3
# 4  8     Osaka       1988      Aoi    90       20   M          4

# %%
# Exercise6-5
pd.merge(df4, df5, how='outer')
# Out:
#    id      city  birth_day     name  math  english  sex  index_num
# 0   0     Tokyo       1990  Hiroshi  20.0     30.0    M        0.0
# 1   1     Osaka       1989    Akiko  30.0     50.0    F        1.0
# 2   2     Kyoto       1992     Yuri   NaN      NaN  NaN        NaN
# 3   3  Hokkaido       1997   Satoru  50.0     50.0    F        2.0
# 4   4     Tokyo       1982   Steeve   NaN      NaN  NaN        NaN
# 5   6     Tokyo       1991   Mituru  70.0     70.0    M        3.0
# 6   8     Osaka       1988      Aoi  90.0     20.0    M        4.0
# 7  11     Kyoto       1990    Tarou   NaN      NaN  NaN        NaN
# 8  12  Hokkaido       1995   Suguru   NaN      NaN  NaN        NaN
# 9  13     Tokyo       1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
#Exercise6-6
data6 = {
    'id':['70','80','90','120','150'],
    'city':['Chiba','Kanagawa','Tokyo','Fukuoka','Okinawa'],
    'birth_year':[1980,1999,1995,1994,1994],
    'name':['Suguru','Kouichi','Satochi','Yukie','Akari']
}
df6 = DataFrame(data6)

pd.concat([df4, df6])
# Out:
#     id      city  birth_day     name  birth_year
# 0    0     Tokyo     1990.0  Hiroshi         NaN
# 1    1     Osaka     1989.0    Akiko         NaN
# 2    2     Kyoto     1992.0     Yuri         NaN
# 3    3  Hokkaido     1997.0   Satoru         NaN
# 4    4     Tokyo     1982.0   Steeve         NaN
# 5    6     Tokyo     1991.0   Mituru         NaN
# 6    8     Osaka     1988.0      Aoi         NaN
# 7   11     Kyoto     1990.0    Tarou         NaN
# 8   12  Hokkaido     1995.0   Suguru         NaN
# 9   13     Tokyo     1981.0   Mitsuo         NaN
# 0   70     Chiba        NaN   Suguru      1980.0
# 1   80  Kanagawa        NaN  Kouichi      1999.0
# 2   90     Tokyo        NaN  Satochi      1995.0
# 3  120   Fukuoka        NaN    Yukie      1994.0
# 4  150   Okinawa        NaN    Akari      1994.0

# %%
# Exercise6-7
import pandas as pd
student_data_math = pd.read_csv('student-mat.csv', sep=';')
student_data_math['age_d'] = student_data_math['age'].map(lambda x: x*2)
student_data_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 age_d
# 0        3     4     1     1       3        6   5   6   6    36
# 1        3     3     1     1       3        4   5   5   6    34
# 2        3     2     2     3       3       10   7   8  10    30
# 3        2     2     1     1       5        2  15  14  15    30
# 4        3     2     1     2       5        4   6  10  10    32
#
# [5 rows x 34 columns]

# %%
# Exercise6-8
absences_bins = [0,1,5,100]
student_data_math_ab_cut_data = pd.cut(student_data_math.absences,absences_bins,right=False)
pd.value_counts(student_data_math_ab_cut_data)
# Out:
# absences
# [5, 100)    151
# [1, 5)      129
# [0, 1)      115
# Name: count, dtype: int64

# %%
# Exercise6-9
student_data_math_ab_qcut_data = pd.qcut(student_data_math.absences, 3)
pd.value_counts(student_data_math_ab_qcut_data)
# Out:
# absences
# (-0.001, 2.0]    183
# (6.0, 75.0]      115
# (2.0, 6.0]        97
# Name: count, dtype: int64

# %%
# Exercise6-10
student_data_math = pd.read_csv('student-mat.csv',sep=';')
student_data_math.groupby(['school'])['G1'].mean()
# Out:
# school
# GP    10.939828
# MS    10.673913
# Name: G1, dtype: float64

# %%
# Exercise6-11
student_data_math.groupby(['school','sex'])[['G1','G2','G3']].mean()
# Out:
#                    G1         G2         G3
# school sex
# GP     F    10.579235  10.398907   9.972678
#        M    11.337349  11.204819  11.060241
# MS     F    10.920000  10.320000   9.920000
#        M    10.380952  10.047619   9.761905

# %%
# Exercise6-12
functions = ['max','min']
student_data_math2 = student_data_math.groupby(['school','sex'])
student_data_math2[['G1','G2','G3']].agg(functions)
# Out:
#             G1      G2      G3
#            max min max min max min
# school sex
# GP     F    18   4  18   0  19   0
#        M    19   3  19   0  20   0
# MS     F    19   6  18   5  19   0
#        M    15   6  16   5  16   0

# %%
# Exercise6-13
import numpy as np
from numpy import nan as NA
import pandas as pd

df2 = pd.DataFrame(np.random.rand(15,6))

df2.iloc[2,0] = NA
df2.iloc[5:8,2] = NA
df2.iloc[7:9,3] = NA
df2.iloc[10,5] = NA

df2.dropna()
# Out:
#            0         1         2         3         4         5
# 0   0.432808  0.955269  0.063154  0.117013  0.520139  0.969413
# 1   0.481991  0.271491  0.417440  0.166404  0.915924  0.918670
# 3   0.759167  0.465484  0.910745  0.242762  0.967406  0.149926
# 4   0.573487  0.688482  0.696446  0.756110  0.849275  0.036253
# 9   0.612868  0.745785  0.913852  0.183446  0.930247  0.445693
# 11  0.002963  0.483218  0.073895  0.932456  0.442240  0.798642
# 12  0.380578  0.754828  0.770546  0.958463  0.435407  0.941961
# 13  0.860993  0.719853  0.970144  0.509109  0.185350  0.324564
# 14  0.372296  0.445449  0.237362  0.543671  0.495631  0.803982

# %%
# Exercise6-14
df2.fillna(0)
# Out:
#            0         1         2         3         4         5
# 0   0.432808  0.955269  0.063154  0.117013  0.520139  0.969413
# 1   0.481991  0.271491  0.417440  0.166404  0.915924  0.918670
# 2   0.000000  0.020739  0.648033  0.512755  0.519960  0.940171
# 3   0.759167  0.465484  0.910745  0.242762  0.967406  0.149926
# 4   0.573487  0.688482  0.696446  0.756110  0.849275  0.036253
# 5   0.234623  0.457778  0.000000  0.592313  0.146052  0.876103
# 6   0.936731  0.326197  0.000000  0.306760  0.858052  0.919125
# 7   0.102226  0.993416  0.000000  0.000000  0.190934  0.835610
# 8   0.656941  0.137530  0.303554  0.000000  0.572621  0.249156
# 9   0.612868  0.745785  0.913852  0.183446  0.930247  0.445693
# 10  0.868534  0.863730  0.058876  0.879173  0.085873  0.000000
# 11  0.002963  0.483218  0.073895  0.932456  0.442240  0.798642
# 12  0.380578  0.754828  0.770546  0.958463  0.435407  0.941961
# 13  0.860993  0.719853  0.970144  0.509109  0.185350  0.324564
# 14  0.372296  0.445449  0.237362  0.543671  0.495631  0.803982

# %%
# Exercise6-15
df2.fillna(df2.mean())
# Out:
#            0         1         2         3         4         5
# 0   0.432808  0.955269  0.063154  0.117013  0.520139  0.969413
# 1   0.481991  0.271491  0.417440  0.166404  0.915924  0.918670
# 2   0.519729  0.020739  0.648033  0.512755  0.519960  0.940171
# 3   0.759167  0.465484  0.910745  0.242762  0.967406  0.149926
# 4   0.573487  0.688482  0.696446  0.756110  0.849275  0.036253
# 5   0.234623  0.457778  0.505337  0.592313  0.146052  0.876103
# 6   0.936731  0.326197  0.505337  0.306760  0.858052  0.919125
# 7   0.102226  0.993416  0.505337  0.515418  0.190934  0.835610
# 8   0.656941  0.137530  0.303554  0.515418  0.572621  0.249156
# 9   0.612868  0.745785  0.913852  0.183446  0.930247  0.445693
# 10  0.868534  0.863730  0.058876  0.879173  0.085873  0.657805
# 11  0.002963  0.483218  0.073895  0.932456  0.442240  0.798642
# 12  0.380578  0.754828  0.770546  0.958463  0.435407  0.941961
# 13  0.860993  0.719853  0.970144  0.509109  0.185350  0.324564
# 14  0.372296  0.445449  0.237362  0.543671  0.495631  0.803982

# %%
import pandas_datareader.data as pdr

# %%
start_date = '2001-01-02'  # Changed date format
end_date = '2016-12-30'  # Changed date format

fx_jpusdata = pdr.DataReader('DEXJPUS','fred', start_date, end_date)

# %%
# Exercise6-16
fx_jpusdata.resample('Y').mean().head()
# Out:
#                DEXJPUS
# DATE
# 2001-12-31  121.568040
# 2002-12-31  125.220438
# 2003-12-31  115.938685
# 2004-12-31  108.150830
# 2005-12-31  110.106932

# %%
# Exercise6-17
fx_jpusdata.rolling(20).mean().dropna()
# Out:
#              DEXJPUS
# DATE
# 2001-02-12  116.6910
# 2001-02-13  116.6920
# 2001-02-14  116.6070
# 2001-02-15  116.5015
# 2001-02-16  116.4130
# ...              ...
# 2016-11-08  104.1600
# 2016-11-09  104.1780
# 2016-11-10  104.3250
# 2016-12-22  115.1555
# 2016-12-23  115.3580
#
# [1593 rows x 1 columns]

# %%
# Comprehensive6-1_1
student_data_math = pd.read_csv('student-mat.csv', sep=';')
student_data_math.groupby(['age','sex'])['G1'].mean().unstack()
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000
# 21         NaN  10.000000
# 22         NaN   6.000000

# %%
# Comprehensive6-1_2
student_data_math.groupby(['age','sex'])['G1'].mean().unstack().dropna()
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000
